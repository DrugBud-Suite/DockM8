# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import rdForceFieldHelpers, AllChem
from rdkit.Chem import SDMolSupplier
from rdkit.Chem import PDBWriter

def load_molecule(file_path):
    """Load a molecule from a file (SDF or PDB) and add explicit hydrogens."""
    if file_path.lower().endswith('.sdf'):
        suppl = SDMolSupplier(file_path, removeHs=False)
        mol = next(suppl)
    elif file_path.lower().endswith('.pdb'):
        mol = Chem.MolFromPDBFile(file_path, removeHs=False)
    else:
        raise ValueError("Unsupported file format. Please use .sdf or .pdb")
    
    if mol is None:
        raise ValueError(f"Failed to load molecule from {file_path}")
    
    mol = Chem.AddHs(mol)
    return mol

def prepare_molecule(mol):
    """Prepare the molecule for force field calculations."""
    mol = Chem.AddHs(mol)
    if not mol.GetNumConformers():
        AllChem.EmbedMolecule(mol, randomSeed=42)
    return mol

def minimize_ligand(ligand, protein, max_iters=500, conf_id=-1):
    """
    Minimize the ligand using MMFF forcefield while keeping the protein fixed.
    
    :param ligand: RDKit Mol object of the ligand
    :param protein: RDKit Mol object of the protein
    :param max_iters: Maximum number of iterations for minimization
    :param conf_id: ID of the conformer to minimize (-1 for the first one)
    :return: Minimized ligand as RDKit Mol object
    """
    # Prepare molecules
    ligand = prepare_molecule(ligand)
    protein = prepare_molecule(protein)
    
    # Create a combined molecule
    combined = Chem.CombineMols(ligand, protein)
    
    try:
        # Set up MMFF properties
        # mp = rdForceFieldHelpers.UFFGetMoleculeProperties(combined)
        # if mp is None:
        #     raise ValueError("Failed to set up MMFF properties. Check your input molecules.")
        
        # Create MMFF force field
        ff = rdForceFieldHelpers.UFFGetMoleculeForceField(combined, confId=0, ignoreInterfragInteractions=False)
        if ff is None:
            raise ValueError("Failed to create force field. Check your input molecules.")
        
        # Fix the protein atoms
        for atom in combined.GetAtoms():
            if atom.GetIdx() >= ligand.GetNumAtoms():  # These are protein atoms
                ff.AddFixedPoint(atom.GetIdx())
        
        # Run the minimization
        result = ff.Minimize(maxIts=10, energyTol=1e-4, forceTol=1e-3)
        
        if result == 1:
            print(f"Minimization did not converge in {max_iters} iterations.")
        elif result == -1:
            print("Minimization failed.")
        else:
            print("Minimization successful.")
        
        # Extract the minimized ligand
        minimized_ligand = Chem.Mol(ligand)
        conf = minimized_ligand.GetConformer()
        for i in range(ligand.GetNumAtoms()):
            conf.SetAtomPosition(i, combined.GetConformer().GetAtomPosition(i))
        
        return minimized_ligand
    
    except ValueError as e:
        print(f"Error during minimization: {str(e)}")
        return None

# %%
ligand_file = "/home/tony/DockM8_v2/tests/test_files/fabind_test/fabind_plus/FCG18472628.sdf"
protein_file = "/home/tony/DockM8_v2/tests/test_files/fabind_test/fabind_plus/pdb/4kd1_p.pdb"

ligand = load_molecule(ligand_file)
protein = load_molecule(protein_file)

minimized_ligand = minimize_ligand(ligand, protein)

# Save the minimized ligand
writer = Chem.SDWriter("/home/tony/DockM8_v2/tests/test_files/fabind_test/fabind_plusminimized_ligand.sdf")
writer.write(minimized_ligand)
writer.close()

print("Minimized ligand saved as 'minimized_ligand.sdf'")
# Out:
# [22:58:16]
#
# ****
# Pre-condition Violation
# RingInfo not initialized
# Violation occurred on line 28 in file /home/conda/feedstock_root/build_artifacts/rdkit_1711521244359/work/Code/GraphMol/RingInfo.cpp
# Failed Expression: df_init
# ----------
# Stacktrace:
#  0# Invar::Invariant::toString[abi:cxx11]() const in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libRDKitRDGeneral.so.1
#  1# Invar::operator<<(std::ostream&, Invar::Invariant const&) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libRDKitRDGeneral.so.1
#  2# RDKit::RingInfo::isAtomInRingOfSize(unsigned int, unsigned int) const in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/../../../../libRDKitGraphMol.so.1
#  3# RDKit::UFF::Tools::addAngles(RDKit::ROMol const&, std::vector<ForceFields::UFF::AtomicParams const*, std::allocator<ForceFields::UFF::AtomicParams const*> > const&, ForceFields::ForceField*) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/../../../../libRDKitForceFieldHelpers.so.1
#  4# RDKit::UFF::constructForceField(RDKit::ROMol&, std::vector<ForceFields::UFF::AtomicParams const*, std::allocator<ForceFields::UFF::AtomicParams const*> > const&, double, int, bool) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/../../../../libRDKitForceFieldHelpers.so.1
#  5# RDKit::UFF::constructForceField(RDKit::ROMol&, double, int, bool) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/../../../../libRDKitForceFieldHelpers.so.1
#  6# RDKit::UFFGetMoleculeForceField(RDKit::ROMol&, double, int, bool) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdForceFieldHelpers.so
#  7# 0x00007FB216D1421A in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdForceFieldHelpers.so
#  8# boost::python::objects::function::call(_object*, _object*) const in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libboost_python310.so.1.84.0
#  9# 0x00007FB28C02C759 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libboost_python310.so.1.84.0
# 10# boost::python::detail::exception_handler::operator()(boost::function0<void> const&) const in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libboost_python310.so.1.84.0
# 11# 0x00007FB20BF19884 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdSLNParse.so
# 12# 0x00007FB2102A2EC4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdMolChemicalFeatures.so
# 13# 0x00007FB2172F2CD4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdChemReactions.so
# 14# 0x00007FB2172F2D24 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdChemReactions.so
# 15# 0x00007FB217CB5CD4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdDepictor.so
# 16# 0x00007FB2184BAB04 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdmolfiles.so
# 17# 0x00007FB2184BAB54 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdmolfiles.so
# 18# 0x00007FB28C0087D4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdCIPLabeler.so
# 19# 0x00007FB2683CC674 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 20# 0x00007FB268361A1D in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 21# 0x00007FB26836159D in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 22# 0x00007FB26836111D in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 23# 0x00007FB268360C9D in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 24# 0x00007FB26836081D in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/Chem/rdchem.so
# 25# 0x00007FB28C0D04A4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/rdBase.so
# 26# 0x00007FB28C0D04F4 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/rdBase.so
# 27# 0x00007FB28C0D0544 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/rdBase.so
# 28# 0x00007FB28C0D0594 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/rdBase.so
# 29# boost::python::handle_exception_impl(boost::function0<void>) in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libboost_python310.so.1.84.0
# 30# 0x00007FB28C029CA3 in /home/tony/miniconda/envs/dockm8/lib/python3.10/site-packages/rdkit/../../../libboost_python310.so.1.84.0
# 31# _PyObject_MakeTpCall in /home/tony/miniconda/envs/dockm8/bin/python
# 32# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 33# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 34# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 35# 0x0000555EEF19AC60 in /home/tony/miniconda/envs/dockm8/bin/python
# 36# PyEval_EvalCode in /home/tony/miniconda/envs/dockm8/bin/python
# 37# 0x0000555EEF1A1DAA in /home/tony/miniconda/envs/dockm8/bin/python
# 38# 0x0000555EEF107BF3 in /home/tony/miniconda/envs/dockm8/bin/python
# 39# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 40# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 41# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 42# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 43# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 44# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 45# 0x0000555EEF1B8A37 in /home/tony/miniconda/envs/dockm8/bin/python
# 46# 0x0000555EEF11253D in /home/tony/miniconda/envs/dockm8/bin/python
# 47# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 48# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 49# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 50# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 51# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 52# 0x0000555EEF113582 in /home/tony/miniconda/envs/dockm8/bin/python
# 53# PyObject_Call in /home/tony/miniconda/envs/dockm8/bin/python
# 54# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 55# 0x0000555EEF113582 in /home/tony/miniconda/envs/dockm8/bin/python
# 56# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 57# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 58# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 59# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 60# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 61# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 62# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 63# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 64# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 65# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 66# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 67# 0x0000555EEF1A4384 in /home/tony/miniconda/envs/dockm8/bin/python
# 68# 0x00007FB2910D3BF6 in /home/tony/miniconda/envs/dockm8/lib/python3.10/lib-dynload/_asyncio.cpython-310-x86_64-linux-gnu.so
# 69# 0x0000555EEF106E8A in /home/tony/miniconda/envs/dockm8/bin/python
# 70# 0x0000555EEF22260C in /home/tony/miniconda/envs/dockm8/bin/python
# 71# 0x0000555EEF0C0D90 in /home/tony/miniconda/envs/dockm8/bin/python
# 72# 0x0000555EEF0FF2A3 in /home/tony/miniconda/envs/dockm8/bin/python
# 73# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 74# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 75# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 76# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 77# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 78# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 79# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 80# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 81# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 82# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 83# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 84# 0x0000555EEF113582 in /home/tony/miniconda/envs/dockm8/bin/python
# 85# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 86# 0x0000555EEF19AC60 in /home/tony/miniconda/envs/dockm8/bin/python
# 87# PyEval_EvalCode in /home/tony/miniconda/envs/dockm8/bin/python
# 88# 0x0000555EEF1A1DAA in /home/tony/miniconda/envs/dockm8/bin/python
# 89# 0x0000555EEF107BF3 in /home/tony/miniconda/envs/dockm8/bin/python
# 90# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 91# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 92# _PyEval_EvalFrameDefault in /home/tony/miniconda/envs/dockm8/bin/python
# 93# _PyFunction_Vectorcall in /home/tony/miniconda/envs/dockm8/bin/python
# 94# 0x0000555EEF1BDB78 in /home/tony/miniconda/envs/dockm8/bin/python
# 95# Py_RunMain in /home/tony/miniconda/envs/dockm8/bin/python
# 96# Py_BytesMain in /home/tony/miniconda/envs/dockm8/bin/python
# 97# 0x00007FB2923B3D90 in /lib/x86_64-linux-gnu/libc.so.6
# 98# __libc_start_main in /lib/x86_64-linux-gnu/libc.so.6
# 99# 0x0000555EEF18E0F1 in /home/tony/miniconda/envs/dockm8/bin/python
# ----------
# ****
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 7
#       4 ligand = load_molecule(ligand_file)
#       5 protein = load_molecule(protein_file)
# ----> 7 minimized_ligand = minimize_ligand(ligand, protein)
#       9 # Save the minimized ligand
#      10 writer = Chem.SDWriter("/home/tony/DockM8_v2/tests/test_files/fabind_test/fabind_plusminimized_ligand.sdf")
#
# Cell In[7], line 54, in minimize_ligand(ligand, protein, max_iters, conf_id)
#      45 combined = Chem.CombineMols(ligand, protein)
#      47 try:
#      48     # Set up MMFF properties
#      49     # mp = rdForceFieldHelpers.UFFGetMoleculeProperties(combined)
#    (...)
#      52
#      53     # Create MMFF force field
# ---> 54     ff = rdForceFieldHelpers.UFFGetMoleculeForceField(combined, confId=0, ignoreInterfragInteractions=False)
#      55     if ff is None:
#      56         raise ValueError("Failed to create force field. Check your input molecules.")
#
# RuntimeError: Pre-condition Violation
# 	RingInfo not initialized
# 	Violation occurred on line 28 in file Code/GraphMol/RingInfo.cpp
# 	Failed Expression: df_init
# 	RDKIT: 2023.09.6
# 	BOOST: 1_84
