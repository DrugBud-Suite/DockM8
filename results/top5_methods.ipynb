# %%
import pandas as pd

EF1_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_EF_1%.csv')
EF1_df
# Out:
#        clustering    consensus  \
# 0       ConvexPLR          NaN
# 1       ConvexPLR          NaN
# 2       ConvexPLR          NaN
# 3       ConvexPLR          NaN
# 4       ConvexPLR          NaN
# ...           ...          ...
# 621616   bestpose     RbR_best
# 621617   bestpose      RbV_avg
# 621618   bestpose     RbV_best
# 621619   bestpose   Zscore_avg
# 621620   bestpose  Zscore_best
#
#                                                   scoring  11betahsd1  \
# 0                                               RFScoreVS        2.78
# 1                                               PLECScore        0.00
# 2                                                 CHEMPLP        0.00
# 3                                            CNN-Affinity        2.78
# 4                                               ConvexPLR        0.00
# ...                                                   ...         ...
# 621616  PLECScore_CHEMPLP_CNN-Affinity_ConvexPLR_AD4_C...        0.00
# ...

# %%
EF1_df['EF1%'] = round(EF1_df.iloc[:, 3:].mean(axis=1), 2)
EF1_df.sort_values(by='EF1%', ascending=False, inplace=True)
EF1_df = EF1_df.head(5)

# %%
DEKOIS_top5 = EF1_df[['clustering', 'consensus', 'scoring', 'EF1%']]
DEKOIS_top5
# Out:
#        clustering    consensus  \
# 560710   bestpose  Zscore_best
# 550360   bestpose  Zscore_best
# 233255    KORP-PL  Zscore_best
# 233263    KORP-PL  Zscore_best
# 237395    KORP-PL  Zscore_best
#
#                                                   scoring   EF1%
# 560710  CHEMPLP_CNN-Score_KORP-PL_RTMScore_GNINA-Affinity  18.02
# 550360          CNN-Score_KORP-PL_RTMScore_GNINA-Affinity  18.02
# 233255                 CNN-Score_KORP-PL_RTMScore_Vinardo  17.97
# 233263          CNN-Score_KORP-PL_RTMScore_GNINA-Affinity  17.87
# 237395         CHEMPLP_CNN-Score_KORP-PL_RTMScore_Vinardo  17.84

# %%
EF05_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_EF_0.5%.csv')
EF05_df['EF0.5%'] = round(EF05_df.iloc[:, 3:].mean(axis=1), 2)
EF05_df = EF05_df[['clustering', 'consensus', 'scoring', 'EF0.5%']]
EF5_df= pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_EF_5%.csv')
EF5_df['EF5%'] = round(EF5_df.iloc[:, 3:].mean(axis=1), 2)
EF5_df = EF5_df[['clustering', 'consensus', 'scoring', 'EF5%']]
AUC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_AUC_ROC.csv')
AUC_df['AUC_ROC'] = round(AUC_df.iloc[:, 3:].mean(axis=1), 2)
AUC_df = AUC_df[['clustering', 'consensus', 'scoring', 'AUC_ROC']]
BEDROC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_BEDROC.csv')
BEDROC_df['BEDROC'] = round(BEDROC_df.iloc[:, 3:].mean(axis=1), 2)
BEDROC_df = BEDROC_df[['clustering', 'consensus', 'scoring', 'BEDROC']]

# %%
DEKOIS_top5 = pd.merge(DEKOIS_top5, EF05_df, on=['clustering', 'consensus', 'scoring'])
DEKOIS_top5 = pd.merge(DEKOIS_top5, EF5_df, on=['clustering', 'consensus', 'scoring'])
DEKOIS_top5 = pd.merge(DEKOIS_top5, AUC_df, on=['clustering', 'consensus', 'scoring'])
DEKOIS_top5 = pd.merge(DEKOIS_top5, BEDROC_df, on=['clustering', 'consensus', 'scoring'])

# %%
DEKOIS_top5.to_csv('/mnt/d/DockM8/FINAL_RESULTS/DEKOIS_2.0x/DEKOIS_RESULTS/results_dockm8_top5.csv', index=False)

# %%
import pandas as pd

EF1_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/results_dockm8_EF_1%.csv')
EF1_df['EF1%'] = round(EF1_df.iloc[:, 3:].mean(axis=1), 2)
EF1_df.sort_values(by='EF1%', ascending=False, inplace=True)
EF1_df = EF1_df.head(5)
DUDE_top5 = EF1_df[['clustering', 'consensus', 'scoring', 'EF1%']]
EF05_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/results_dockm8_EF_0.5%.csv')
EF05_df['EF0.5%'] = round(EF05_df.iloc[:, 3:].mean(axis=1), 2)
EF05_df = EF05_df[['clustering', 'consensus', 'scoring', 'EF0.5%']]
EF5_df= pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/results_dockm8_EF_5%.csv')
EF5_df['EF5%'] = round(EF5_df.iloc[:, 3:].mean(axis=1), 2)
EF5_df = EF5_df[['clustering', 'consensus', 'scoring', 'EF5%']]
AUC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/results_dockm8_AUC_ROC.csv')
AUC_df['AUC_ROC'] = round(AUC_df.iloc[:, 3:].mean(axis=1), 2)
AUC_df = AUC_df[['clustering', 'consensus', 'scoring', 'AUC_ROC']]
BEDROC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/results_dockm8_BEDROC.csv')
BEDROC_df['BEDROC'] = round(BEDROC_df.iloc[:, 3:].mean(axis=1), 2)
BEDROC_df = BEDROC_df[['clustering', 'consensus', 'scoring', 'BEDROC']]
DUDE_top5 = pd.merge(DUDE_top5, EF05_df, on=['clustering', 'consensus', 'scoring'])
DUDE_top5 = pd.merge(DUDE_top5, EF5_df, on=['clustering', 'consensus', 'scoring'])
DUDE_top5 = pd.merge(DUDE_top5, AUC_df, on=['clustering', 'consensus', 'scoring'])
DUDE_top5 = pd.merge(DUDE_top5, BEDROC_df, on=['clustering', 'consensus', 'scoring'])
DUDE_top5.to_csv('/mnt/d/DockM8/FINAL_RESULTS/DUD-E/DUD-E_RESULTS/DUDE_top5.csv', index=False)

# %%
import pandas as pd

EF1_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_EF_1%.csv')
EF1_df['EF1%'] = round(EF1_df.iloc[:, 3:].mean(axis=1), 2)
EF1_df.sort_values(by='EF1%', ascending=False, inplace=True)
EF1_df = EF1_df.head(5)
LITPCBA_top5 = EF1_df[['clustering', 'consensus', 'scoring', 'EF1%']]
EF05_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_EF_0.5%.csv')
EF05_df['EF0.5%'] = round(EF05_df.iloc[:, 3:].mean(axis=1), 2)
EF05_df = EF05_df[['clustering', 'consensus', 'scoring', 'EF0.5%']]
EF5_df= pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_EF_5%.csv')
EF5_df['EF5%'] = round(EF5_df.iloc[:, 3:].mean(axis=1), 2)
EF5_df = EF5_df[['clustering', 'consensus', 'scoring', 'EF5%']]
AUC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_AUC_ROC.csv')
AUC_df['AUC_ROC'] = round(AUC_df.iloc[:, 3:].mean(axis=1), 2)
AUC_df = AUC_df[['clustering', 'consensus', 'scoring', 'AUC_ROC']]
BEDROC_df = pd.read_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_BEDROC.csv')
BEDROC_df['BEDROC'] = round(BEDROC_df.iloc[:, 3:].mean(axis=1), 2)
BEDROC_df = BEDROC_df[['clustering', 'consensus', 'scoring', 'BEDROC']]
LITPCBA_top5 = pd.merge(LITPCBA_top5, EF05_df, on=['clustering', 'consensus', 'scoring'])
LITPCBA_top5 = pd.merge(LITPCBA_top5, EF5_df, on=['clustering', 'consensus', 'scoring'])
LITPCBA_top5 = pd.merge(LITPCBA_top5, AUC_df, on=['clustering', 'consensus', 'scoring'])
LITPCBA_top5 = pd.merge(LITPCBA_top5, BEDROC_df, on=['clustering', 'consensus', 'scoring'])
LITPCBA_top5.to_csv('/mnt/d/DockM8/FINAL_RESULTS/lit-pcba/LIT-PCBA_RESULTS/results_dockm8_top5.csv', index=False)
