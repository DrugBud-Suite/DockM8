# %% [markdown]
# # DockM8 v1.1: Ensemble Docking Workflow
#
# Ensemble docking uses multiple receptor conformations to improve hit identification by finding compounds that score well across all structures.
#
# **Workflow:**
# 1. Prepare compound library (shared across all receptors)
# 2. For each receptor: protein prep, pocket finding, docking, pose selection, rescoring, consensus
# 3. Ensemble aggregation: select top-scoring compounds from each receptor and find the intersection
# 4. Optional PoseBusters validation
#
# **When to use:** When you have multiple crystal structures or MD snapshots of your target protein.

# %%
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

from scripts.consensus.consensus import apply_consensus_scoring
from scripts.docking.docking import DOCKING_PROGRAMS, dockm8_docking
from scripts.library_preparation.library_preparation import prepare_library
from scripts.pocket_finding.pocket_finder import find_pocket
from scripts.pose_selection.pose_selection import select_poses
from scripts.pose_selection.posebusters import bust_poses
from scripts.protein_preparation.protein_preparation import prepare_protein
from scripts.rescoring.rescoring import RESCORING_FUNCTIONS, rescore_poses
from scripts.utilities.fast_sdf_loader import fast_load_sdf
from scripts.utilities.fast_sdf_writer import fast_write_sdf

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Configuration
#
# Define the receptor ensemble. Each receptor must be paired with its reference ligand for pocket identification.
#
# ### Ensemble-Specific Parameters
# - **receptors**: List of paths to protein structure files (.pdb)
# - **ref_ligands**: Corresponding reference ligands (.sdf) for each receptor
# - **ensemble_top_percent**: Top X% of compounds from each receptor to consider (default: 1.0 = top 1%)
#
# ### Other Parameters
# See the standard `dockm8.ipynb` notebook for documentation of all other parameters.

# %%
CWD = Path(os.getcwd())
software = CWD / "software"

receptors = [
    CWD / "test_data" / "1fvv_p.pdb",
    CWD / "test_data" / "4kd1_p.pdb",
]
ref_ligands = [
    CWD / "test_data" / "1fvv_l.sdf",
    CWD / "test_data" / "4kd1_l.sdf",
]

docking_library = CWD / "test_data" / "library.sdf"

pocket_mode = "Reference"
protonation = "GypsumDL"
conformers = "GypsumDL"

docking_programs = ["PLANTS"]
n_poses = 10
exhaustiveness = 8

pose_selection_method = "bestpose"

rescoring_functions = ["GNINA-Affinity", "CNN-Score", "CNN-Affinity", "AD4", "CHEMPLP", "RFScoreVS"]

consensus_method = "ecr"
consensus_aggregation = "best"

ensemble_top_percent = 1.0

n_cpus = max(1, int(os.cpu_count() * 0.9))

ensemble_dir = CWD / "test_data" / "ensemble_results"
ensemble_dir.mkdir(exist_ok=True)

receptor_pairs = list(zip(receptors, ref_ligands))
print(f"Ensemble with {len(receptor_pairs)} receptors:")
for r, l in receptor_pairs:
    print(f"  {r.stem} (ref: {l.stem})")

# %% [markdown]
# ## Step 1: Prepare Compound Library
#
# Library preparation is receptor-independent, so we prepare it once and share across all receptors.

# %%
shared_library_sdf = ensemble_dir / "final_library.sdf"

if not shared_library_sdf.exists():
    prepare_library(
        input_data=docking_library,
        protonation=protonation,
        conformers=conformers,
        software=software,
        n_cpus=n_cpus,
        output_sdf=shared_library_sdf,
    )
    print(f"Prepared library: {shared_library_sdf}")
else:
    print(f"Using existing library: {shared_library_sdf}")

# %% [markdown]
# ## Step 2: Process Each Receptor
#
# For each receptor in the ensemble, run the full pipeline: protein preparation, pocket finding, docking, pose selection, rescoring, and consensus scoring.

# %%
results_by_receptor = {}

for receptor_path, ref_ligand_path in receptor_pairs:
    receptor_name = receptor_path.stem
    receptor_dir = ensemble_dir / receptor_name
    receptor_dir.mkdir(exist_ok=True)
    print(f"\n{'='*60}")
    print(f"Processing receptor: {receptor_name}")
    print(f"{'='*60}")

    prepared_receptor = prepare_protein(
        protein_file_or_code=receptor_path,
        output_dir=receptor_dir,
        protonation_method="protoss",
    )
    print(f"  Prepared receptor: {prepared_receptor}")

    pocket_definition = find_pocket(
        mode=pocket_mode,
        receptor=prepared_receptor,
        ligand=ref_ligand_path,
        radius=10,
    )
    print(f"  Pocket: {pocket_definition}")

    all_poses_path = dockm8_docking(
        library=shared_library_sdf,
        w_dir=receptor_dir,
        protein_file=prepared_receptor,
        pocket_definition=pocket_definition,
        software=software,
        docking_programs=docking_programs,
        exhaustiveness=exhaustiveness,
        n_poses=n_poses,
        n_cpus=n_cpus,
    )
    print(f"  Docking complete: {all_poses_path}")

    selected_sdf = receptor_dir / f"{pose_selection_method}_selected.sdf"
    selected = select_poses(
        selection_method=pose_selection_method,
        poses_input=all_poses_path,
        protein_file=prepared_receptor,
        pocket_definition=pocket_definition,
        software=software,
        output_file=selected_sdf,
        n_cpus=n_cpus,
    )
    print(f"  Selected {len(selected)} poses")

    rescored_sdf = receptor_dir / f"{pose_selection_method}_rescored.sdf"
    rescored = rescore_poses(
        protein_file=prepared_receptor,
        pocket_definition=pocket_definition,
        software=software,
        poses=selected_sdf,
        functions=rescoring_functions,
        n_cpus=n_cpus,
        output_file=rescored_sdf,
    )
    print(f"  Rescored {len(rescored)} poses")

    score_cols = [c for c in rescored.columns if c in RESCORING_FUNCTIONS]
    scoring_csv = receptor_dir / "scores.csv"
    rescored[["ID"] + score_cols].to_csv(scoring_csv, index=False)

    consensus_csv = receptor_dir / f"{consensus_method}_{consensus_aggregation}.csv"
    apply_consensus_scoring(
        data=scoring_csv,
        method=consensus_method,
        columns=score_cols,
        id_column="ID",
        aggregation=consensus_aggregation,
        output=consensus_csv,
        normalize=True,
    )
    print(f"  Consensus saved: {consensus_csv}")

    results_by_receptor[receptor_name] = {
        "consensus": consensus_csv,
        "rescored": rescored_sdf,
        "receptor": prepared_receptor,
    }

print(f"\nProcessed {len(results_by_receptor)} receptors successfully")

# %% [markdown]
# ## Step 3: Ensemble Aggregation
#
# Identify compounds that appear in the top percentile across ALL receptor conformations:
# 1. For each receptor, load consensus scores
# 2. Calculate the score threshold for the top X%
# 3. Select compounds above that threshold
# 4. Find the intersection across all receptors

# %%
all_receptor_dfs = []
merged_df = pd.DataFrame()

for receptor_name, receptor_data in results_by_receptor.items():
    df = pd.read_csv(receptor_data["consensus"])
    score_columns = [col for col in df.columns if col != "ID"]

    if score_columns:
        score_col = score_columns[0]
        threshold = np.percentile(df[score_col].values, 100 - ensemble_top_percent)
        top_mask = df[score_col] >= threshold
        top_df = df.loc[top_mask, ["ID", score_col]].copy()
        top_df = top_df.rename(columns={score_col: f"score_{receptor_name}"})
        all_receptor_dfs.append(top_df)
        print(f"  {receptor_name}: {len(top_df)} compounds in top {ensemble_top_percent}%")

if all_receptor_dfs:
    merged_df = all_receptor_dfs[0]
    for i in range(1, len(all_receptor_dfs)):
        merged_df = pd.merge(merged_df, all_receptor_dfs[i], on="ID", how="inner")

    final_output = ensemble_dir / "final_ensemble_results.csv"
    merged_df.to_csv(final_output, index=False)
    print(f"\nFound {len(merged_df)} compounds in top {ensemble_top_percent}% across ALL {len(all_receptor_dfs)} receptors")
    print(merged_df.head(10))
else:
    print("No valid results from any receptor")

# %% [markdown]
# ## Step 4 (Optional): PoseBusters Validation
#
# Validate ensemble hit poses from each receptor for physical/chemical plausibility.

# %%
if len(merged_df) > 0:
    ensemble_hit_ids = set(merged_df["ID"].values)
    print(f"Validating {len(ensemble_hit_ids)} ensemble hits with PoseBusters\n")

    for receptor_name, receptor_data in results_by_receptor.items():
        busted_output = ensemble_dir / receptor_name / f"{pose_selection_method}_busted.sdf"
        busted_path = bust_poses(
            poses_path=receptor_data["rescored"],
            protein_file=receptor_data["receptor"],
            output_path=busted_output,
            n_cpus=n_cpus,
        )
        print(f"  {receptor_name}: validated poses at {busted_path}")
